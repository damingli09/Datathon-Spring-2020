# %%
import pandas as pd
import csv

# %%
df = pd.read_csv('weather.csv')

# %%
df.head()
# Out:
#           DATE REPORT_TYPE  DailyAverageDewPointTemperature  \
# 0  1/1/13 0:51       FM-15                              NaN
# 1  1/1/13 1:51       FM-15                              NaN
# 2  1/1/13 2:51       FM-15                              NaN
# 3  1/1/13 3:51       FM-15                              NaN
# 4  1/1/13 4:51       FM-15                              NaN
#
#    DailyAverageDryBulbTemperature  DailyAverageWetBulbTemperature  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
#
#    DailyAverageWindSpeed  DailyMaximumDryBulbTemperature  \
# 0                    NaN                             NaN
# 1                    NaN                             NaN
# ...

# %%
df = df.loc[:,['DATE','DailyAverageWetBulbTemperature', 'DailyAverageWindSpeed','DailyPrecipitation','DailySnowfall']]

# %%
df.head()
# Out:
#           DATE  DailyAverageWetBulbTemperature  DailyAverageWindSpeed  \
# 0  1/1/13 0:51                             NaN                    NaN
# 1  1/1/13 1:51                             NaN                    NaN
# 2  1/1/13 2:51                             NaN                    NaN
# 3  1/1/13 3:51                             NaN                    NaN
# 4  1/1/13 4:51                             NaN                    NaN
#
#    DailyPrecipitation  DailySnowfall
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#              DATE  DailyAverageWetBulbTemperature  DailyAverageWindSpeed  \
# 24   1/1/13 23:59                            31.0                    7.0
# 51   1/2/13 23:59                            23.0                    5.8
# 76   1/3/13 23:59                            24.0                    4.5
# 101  1/4/13 23:59                            29.0                    8.0
# 126  1/5/13 23:59                            30.0                    6.6
#
#      DailyPrecipitation  DailySnowfall
# 24                  0.0            0.0
# 51                  0.0            0.0
# 76                  0.0            0.0
# 101                 0.0            0.0
# 126                 0.0            0.0

# %%
df['date'] = pd.to_datetime(df['DATE'])

# %%
df['start_weekday'] = df['date'].dt.weekday

# %%
df.head()
# Out:
#              DATE  DailyAverageWetBulbTemperature  DailyAverageWindSpeed  \
# 24   1/1/13 23:59                            31.0                    7.0
# 51   1/2/13 23:59                            23.0                    5.8
# 76   1/3/13 23:59                            24.0                    4.5
# 101  1/4/13 23:59                            29.0                    8.0
# 126  1/5/13 23:59                            30.0                    6.6
#
#      DailyPrecipitation  DailySnowfall        date
# 24                  0.0            0.0  2013-01-01
# 51                  0.0            0.0  2013-01-02
# 76                  0.0            0.0  2013-01-03
# 101                 0.0            0.0  2013-01-04
# 126                 0.0            0.0  2013-01-05

# %%
df = df[df['start_weekday'].isin([0,1,2,3,4])] # only weekdays

# %%
df.to_csv('weather_clean.csv')
